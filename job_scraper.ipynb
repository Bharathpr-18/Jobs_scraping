# %%
import requests
from bs4 import BeautifulSoup
import csv
print("imported")
# Out:
# imported

# %%
url = "https://realpython.github.io/fake-jobs/"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
job_cards = soup.find_all("div",class_="card-content")
print(f'Thre are {len(job_cards)} Jobs.')
# Out:
# There are 100 Jobs.

# %%
first_job = job_cards[0]

title = first_job.find("h2").text.strip()
company = first_job.find("h3").text.strip()
location = first_job.find("p", class_="location").text.strip()
# Out:
# 'Stewartbury, AA'

# %%
links = first_job.find_all("a")
job_detail_url = links[1]['href']
job_detail_url
# Out:
# 'https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html'

# %%
jobs = []
for job in job_cards:
    title = job.find("h2").text.strip()
    company = job.find("h3").text.strip()
    location = job.find("p", class_="location").text.strip()
    links = job.find_all("a")
    job_url = links[1]['href']
    print(f'{title},{company},{location},{job_url}')
    jobs.append([title,company,location,job_url])
# Out:
# Senior Python Developer,Payne, Roberts and Davis,Stewartbury, AA,https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html
# Energy engineer,Vasquez-Davidson,Christopherville, AA,https://realpython.github.io/fake-jobs/jobs/energy-engineer-1.html
# Legal executive,Jackson, Chambers and Levy,Port Ericaburgh, AA,https://realpython.github.io/fake-jobs/jobs/legal-executive-2.html
# Fitness centre manager,Savage-Bradley,East Seanview, AP,https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3.html
# Product manager,Ramirez Inc,North Jamieview, AP,https://realpython.github.io/fake-jobs/jobs/product-manager-4.html
# Medical technical officer,Rogers-Yates,Davidville, AP,https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5.html
# Physiological scientist,Kramer-Klein,South Christopher, AE,https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6.html
# ...

# %%
with open('jobs.csv',"w",newline='',encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow([
        "Title",
        "Company",
        "Location",
        "job_details"
    ])

    writer.writerows(jobs)
    print("done")
# Out:
# Done

# %%
import pandas as pd

# %%
df = pd.read_csv("jobs.csv")

# %%
df.head()
# Out:
#                      Title                     Company              Location  \
# 0  Senior Python Developer    Payne, Roberts and Davis       Stewartbury, AA
# 1          Energy engineer            Vasquez-Davidson  Christopherville, AA
# 2          Legal executive  Jackson, Chambers and Levy   Port Ericaburgh, AA
# 3   Fitness centre manager              Savage-Bradley     East Seanview, AP
# 4          Product manager                 Ramirez Inc   North Jamieview, AP
#
#                                          job_details
# 0  https://realpython.github.io/fake-jobs/jobs/se...
# 1  https://realpython.github.io/fake-jobs/jobs/en...
# 2  https://realpython.github.io/fake-jobs/jobs/le...
# 3  https://realpython.github.io/fake-jobs/jobs/fi...
# 4  https://realpython.github.io/fake-jobs/jobs/pr...

# %%
df.isnull().sum()
# Out:
# Title          0
# Company        0
# Location       0
# job_details    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        100 non-null    object
#  1   Company      100 non-null    object
#  2   Location     100 non-null    object
#  3   job_details  100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB
